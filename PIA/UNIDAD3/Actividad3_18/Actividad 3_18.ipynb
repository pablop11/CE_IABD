# %% [markdown]
# ## Actividad 3_18: Clasificación de Pistachos

# %% [markdown]
# <div style="border-style:groove;border-width:thin;padding:10px">
# Antes de empezar, vamos a importar los datos. En la misma carpeta de este notebook deberías tener una carpeta llamada training. Dentro de ésta estarán las imágenes separadas en dos carpetas, cada una con un tipo.
# </div>

# %%
# Datos y preprocesamiento
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Modelos de Clasificación
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# Modelos de Regresión
from sklearn.svm import SVR, LinearSVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from tensorflow import keras

# Métricas de Clasificación
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix
)

# Métricas de Regresión
from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
    r2_score
)

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8-darkgrid')

print("Todas las librerías importadas correctamente")
# Out:
# Todas las librerías importadas correctamente

# %%
from os import listdir
from numpy import asarray
from numpy import save
import tensorflow as tf
#Deshabilitar la GPU:
#tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array

folders = listdir('./pistachos')
#Clase Kirmizi será la clase 0.0
#Clase Siirt será la clase 1.0


photos =  []
labels = []

# %%
#2. IMPORTAMOS LOS DATOS:
for idx,folder in enumerate(folders):
    for file in listdir('./pistachos/'+folder):
        #Cargamos la imagen.
        #load_img sirve para cargar las imágenes en memoria. Tiene distintos parámetros para modificar como se cargan las imágenes.
        # target_size=(256, 256)
        photo = load_img('./pistachos/'+folder+'/' + file, color_mode="grayscale", target_size=(128, 128)) 
        #Convertimos la imagen a un array.
        photo = img_to_array(photo)
        #Los guardamos en las listas.
        photos.append(photo)
        labels.append(float(idx))
        del photo
    print(idx)
# Out:
# 0
# 1

# %%
photos = np.array(photos)
labels = np.array(labels)

# %%
photos.shape
# Out:
# (1813, 600, 600, 1)

# %%
X = photos
y = labels

# %%
# X = X/255.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

# %%
X_train_full = X_train/255.0
X_test_full = X_test/255.0

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train)

# %%
print(X_train.shape)
# Out:
# (1223, 600, 600, 1)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=X_train.shape[1:]))  
model.add(keras.layers.Dense(900, activation='relu'))
model.add(keras.layers.Dense(500, activation='relu'))
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer=keras.optimizers.SGD(learning_rate=0.01),metrics=['accuracy'])

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=1000, validation_data=(X_valid, y_valid), callbacks=[early_stopping_cb])
# Out:
# Epoch 1/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 21s 528ms/step - accuracy: 0.5748 - loss: 1.3629 - val_accuracy: 0.5956 - val_loss: 0.7511
# Epoch 2/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 406ms/step - accuracy: 0.7220 - loss: 0.5665 - val_accuracy: 0.4118 - val_loss: 1.0604
# Epoch 3/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 421ms/step - accuracy: 0.7555 - loss: 0.5009 - val_accuracy: 0.7941 - val_loss: 0.4545
# Epoch 4/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 407ms/step - accuracy: 0.7735 - loss: 0.4661 - val_accuracy: 0.7623 - val_loss: 0.4992
# Epoch 5/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 406ms/step - accuracy: 0.7899 - loss: 0.4269 - val_accuracy: 0.7721 - val_loss: 0.5091
# Epoch 6/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 406ms/step - accuracy: 0.8070 - loss: 0.4228 - val_accuracy: 0.6618 - val_loss: 0.7503
# Epoch 7/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 408ms/step - accuracy: 0.8046 - loss: 0.4237 - val_accuracy: 0.7451 - val_loss: 0.5741
# Epoch 8/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 22s 565ms/step - accuracy: 0.8128 - loss: 0.4116 - val_accuracy: 0.8211 - val_loss: 0.4019
# Epoch 9/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 17s 434ms/step - accuracy: 0.8054 - loss: 0.4115 - val_accuracy: 0.8407 - val_loss: 0.3782
# Epoch 10/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 407ms/step - accuracy: 0.8103 - loss: 0.3965 - val_accuracy: 0.7892 - val_loss: 0.4537
# Epoch 11/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 19s 494ms/step - accuracy: 0.8332 - loss: 0.3848 - val_accuracy: 0.8431 - val_loss: 0.3716
# Epoch 12/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 410ms/step - accuracy: 0.8275 - loss: 0.3839 - val_accuracy: 0.7819 - val_loss: 0.4511
# Epoch 13/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 409ms/step - accuracy: 0.8193 - loss: 0.3969 - val_accuracy: 0.8333 - val_loss: 0.3813
# Epoch 14/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 420ms/step - accuracy: 0.8234 - loss: 0.3880 - val_accuracy: 0.7745 - val_loss: 0.4688
# Epoch 15/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 417ms/step - accuracy: 0.8234 - loss: 0.3842 - val_accuracy: 0.8088 - val_loss: 0.4000
# Epoch 16/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 417ms/step - accuracy: 0.8193 - loss: 0.3907 - val_accuracy: 0.7721 - val_loss: 0.5037
# Epoch 17/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 415ms/step - accuracy: 0.8373 - loss: 0.3710 - val_accuracy: 0.7843 - val_loss: 0.5209
# Epoch 18/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 407ms/step - accuracy: 0.8258 - loss: 0.3733 - val_accuracy: 0.8088 - val_loss: 0.4044
# Epoch 19/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 407ms/step - accuracy: 0.8357 - loss: 0.3631 - val_accuracy: 0.7966 - val_loss: 0.4647
# Epoch 20/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 406ms/step - accuracy: 0.8496 - loss: 0.3584 - val_accuracy: 0.7941 - val_loss: 0.4175
# Epoch 21/1000
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 16s 407ms/step - accuracy: 0.8299 - loss: 0.3702 - val_accuracy: 0.7990 - val_loss: 0.4347

# %%
# history = model.fit(X_train, y_train, epochs=300, validation_split=0.1)
# acuracy_test = model.evaluate(X_test, y_test)

# %%
model.evaluate(X_test, y_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8462 - loss: 28.1686
# [28.168590545654297, 0.8461538553237915]

# %%
history.history
# Out:
# {'accuracy': [0.5748160481452942,
#   0.7219951152801514,
#   0.7555192112922668,
#   0.7735077738761902,
#   0.7898610234260559,
#   0.8070318698883057,
#   0.8045789003372192,
#   0.8127555251121521,
#   0.805396556854248,
#   0.8103025555610657,
#   0.8331970572471619,
#   0.8274734020233154,
#   0.8192968368530273,
#   0.8233851194381714,
#   0.8233851194381714,
#   0.8192968368530273,
#   0.8372853398323059,
#   0.8258380889892578,
#   0.8356500267982483,
#   0.8495503067970276,
#   0.8299264311790466],
#  'loss': [1.36293625831604,
#   0.5664756298065186,
#   0.5009377598762512,
#   0.46612444519996643,
#   0.42689576745033264,
#   0.4227599799633026,
#   0.42368459701538086,
#   0.41158413887023926,
#   0.4114776849746704,
#   0.39649373292922974,
#   0.3848268687725067,
#   0.38388729095458984,
#   0.39685481786727905,
#   0.38801833987236023,
#   0.38424500823020935,
#   0.3907153904438019,
#   0.37099406123161316,
#   0.3733099699020386,
#   0.3631156086921692,
#   0.3584285378456116,
#   0.3702147901058197],
#  'val_accuracy': [0.595588207244873,
#   0.4117647111415863,
#   0.7941176295280457,
#   0.7622548937797546,
#   0.7720588445663452,
#   0.6617646813392639,
#   0.7450980544090271,
#   0.8210784196853638,
#   0.8406862616539001,
#   0.7892156839370728,
#   0.843137264251709,
#   0.781862735748291,
#   0.8333333134651184,
#   0.7745097875595093,
#   0.8088235259056091,
#   0.7720588445663452,
#   0.7843137383460999,
#   0.8088235259056091,
#   0.7965686321258545,
#   0.7941176295280457,
#   0.7990196347236633],
#  'val_loss': [0.7511172294616699,
#   1.060355305671692,
#   0.45453059673309326,
#   0.4992333948612213,
#   0.5090932250022888,
#   0.7503347396850586,
#   0.5740901231765747,
#   0.40194228291511536,
#   0.3781883418560028,
#   0.453662633895874,
#   0.3715580701828003,
#   0.45114484429359436,
#   0.38129493594169617,
#   0.4687756299972534,
#   0.4000408947467804,
#   0.5036723017692566,
#   0.5208921432495117,
#   0.40442806482315063,
#   0.4646831452846527,
#   0.4174920618534088,
#   0.434664249420166]}

# %%
# model.save("model_pablo.keras")
