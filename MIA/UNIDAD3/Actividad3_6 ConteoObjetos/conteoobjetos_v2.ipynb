# %%
from ultralytics import YOLO 
model = YOLO('yolo11n.pt')

# %%
from ultralytics import YOLO 
 
# 1. Cargar un modelo pre-entrenado (YOLOv8 nano es rápido y ligero) 
model = YOLO('yolo11n.pt')  
 
# 2. Entrenar el modelo 
results = model.train( 
    data='drinks.v1i.yolov11/data.yaml',  
    epochs=20,                # Número de vueltas al dataset 
    imgsz=640,                # Tamaño de la imagen 
    plots=True,
    device=0
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235 🚀 Python-3.10.19 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 16083MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=drinks.v1i.yolov11/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/runs/detect/train3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=37
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    437887  ultralytics.nn.modules.head.Detect           [37, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,597,055 parameters, 2,597,039 gradients, 6.5 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3312.1±1359.1 MB/s, size: 33.9 KB)
# train: Scanning /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/drinks.v1i.yolov11/train/labels... 618 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 618/618 1.4Kit/s 0.5s<0.0s
# train: New cache created: /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/drinks.v1i.yolov11/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1366.9±935.6 MB/s, size: 32.2 KB)
# val: Scanning /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/drinks.v1i.yolov11/valid/labels... 59 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 59/59 2.3Kit/s 0.0s
# val: New cache created: /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/drinks.v1i.yolov11/valid/labels.cache
# Plotting labels to /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000244, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/runs/detect/train3
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      3.69G      1.709       5.03      1.465        415        640: 100% ━━━━━━━━━━━━ 39/39 3.5it/s 11.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.2s/it 2.5s4.2s
#                    all         59       1705          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      3.71G      1.325      4.586      1.085        381        640: 100% ━━━━━━━━━━━━ 39/39 9.5it/s 4.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 11.0it/s 0.2s
#                    all         59       1705     0.0578     0.0457     0.0382     0.0285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      3.73G      1.235      4.279      1.022        384        640: 100% ━━━━━━━━━━━━ 39/39 9.7it/s 4.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 10.1it/s 0.2s.4s
#                    all         59       1705     0.0684      0.279     0.0816     0.0569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      3.75G       1.21      3.983      1.009        398        640: 100% ━━━━━━━━━━━━ 39/39 9.8it/s 4.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 10.0it/s 0.2s.4s
#                    all         59       1705     0.0533      0.436      0.107     0.0726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      3.76G      1.214      3.686      1.018        546        640: 100% ━━━━━━━━━━━━ 39/39 9.6it/s 4.1s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 10.1it/s 0.2s.4s
#                    all         59       1705     0.0619      0.487      0.136     0.0876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      3.77G      1.193      3.286      1.029        304        640: 100% ━━━━━━━━━━━━ 39/39 9.8it/s 4.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.8it/s 0.2s0.4s
#                    all         59       1705      0.378      0.204      0.153      0.103
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      3.79G       1.19      2.973      1.039        501        640: 100% ━━━━━━━━━━━━ 39/39 9.8it/s 4.0s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.8it/s 0.2s0.4s
#                    all         59       1705      0.368      0.276      0.199      0.132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20       3.8G       1.18       2.69      1.043        313        640: 100% ━━━━━━━━━━━━ 39/39 9.7it/s 4.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.6it/s 0.2s0.4s
#                    all         59       1705       0.48      0.318      0.244      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      3.82G      1.174      2.422      1.063        702        640: 100% ━━━━━━━━━━━━ 39/39 9.8it/s 4.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.7it/s 0.2s0.4s
#                    all         59       1705      0.573       0.32       0.31       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      3.83G      1.168      2.226      1.066        515        640: 100% ━━━━━━━━━━━━ 39/39 9.7it/s 4.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.5it/s 0.2s0.4s
#                    all         59       1705      0.557       0.36      0.347      0.234
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      3.85G      1.119      1.858      1.104        262        640: 100% ━━━━━━━━━━━━ 39/39 9.7it/s 4.0s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 8.8it/s 0.2s0.4s
#                    all         59       1705      0.606      0.407      0.402      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      3.86G      1.073      1.723      1.088        247        640: 100% ━━━━━━━━━━━━ 39/39 11.0it/s 3.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.2it/s 0.2s0.4s
#                    all         59       1705      0.649      0.413      0.418      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      3.88G      1.062      1.618      1.089        303        640: 100% ━━━━━━━━━━━━ 39/39 10.9it/s 3.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.2it/s 0.2s0.4s
#                    all         59       1705      0.674      0.433      0.448      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      3.89G      1.061      1.546      1.082        272        640: 100% ━━━━━━━━━━━━ 39/39 10.9it/s 3.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.2it/s 0.2s0.4s
#                    all         59       1705       0.68      0.461      0.474      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      3.91G      1.055      1.503       1.08        334        640: 100% ━━━━━━━━━━━━ 39/39 10.9it/s 3.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.3it/s 0.2s0.4s
#                    all         59       1705      0.583      0.506      0.494       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      3.92G      1.023      1.445      1.065        252        640: 100% ━━━━━━━━━━━━ 39/39 11.0it/s 3.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.4it/s 0.2s0.4s
#                    all         59       1705      0.685      0.486      0.502      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      3.94G      1.006      1.401       1.07        274        640: 100% ━━━━━━━━━━━━ 39/39 10.9it/s 3.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.5it/s 0.2s0.4s
#                    all         59       1705      0.595      0.523      0.517      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      3.95G     0.9928      1.366      1.067        256        640: 100% ━━━━━━━━━━━━ 39/39 11.0it/s 3.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.2it/s 0.2s0.4s
#                    all         59       1705      0.702      0.484      0.516      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      3.97G     0.9746       1.34      1.051        254        640: 100% ━━━━━━━━━━━━ 39/39 11.0it/s 3.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.3it/s 0.2s0.4s
#                    all         59       1705      0.626      0.522      0.529      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      3.98G     0.9814      1.358      1.059        285        640: 100% ━━━━━━━━━━━━ 39/39 11.1it/s 3.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.3it/s 0.2s0.4s
#                    all         59       1705      0.608      0.529      0.533      0.367
#
# 20 epochs completed in 0.027 hours.
# Optimizer stripped from /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/runs/detect/train3/weights/last.pt, 5.5MB
# Optimizer stripped from /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/runs/detect/train3/weights/best.pt, 5.5MB
#
# Validating /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.10.19 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 16083MiB)
# YOLO11n summary (fused): 100 layers, 2,589,367 parameters, 0 gradients, 6.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 9.8it/s 0.2s
#                    all         59       1705      0.635       0.53      0.533      0.367
#                    7up         26         68      0.482      0.824      0.779      0.514
#               7up-chai         24         52      0.589      0.962        0.9      0.648
#                another          6         29          0          0     0.0166     0.0119
#               aquafina         35        178      0.779      0.978       0.94      0.654
#               goodmood         14         37      0.236      0.486      0.267      0.199
#       minrinda-sodakem          1          3          1          0          0          0
#            mirinda-cam          8         22      0.103      0.227      0.128     0.0717
#       mirinda-cam-chai          8         17      0.835      0.941       0.97      0.704
#             mirinda-me         15         45      0.359      0.756      0.603      0.416
#        mirinda-sodakem         21         38      0.487      0.789      0.673      0.446
#   mirinda-sodakem-chai          4         12          1          0          0          0
#           mirinda-xaxi         19         57          0          0      0.169      0.104
#      mirinda-xaxi-chai         21         82      0.652      0.801      0.811      0.584
#              olong-tea         28        120       0.69      0.833      0.813      0.553
#         olong-tea-chai          7         50      0.272        0.3      0.301      0.202
#          olong-teaplus         20         53      0.652      0.868      0.797      0.552
#     olong-teaplus-chai          7         27          1     0.0656      0.385      0.301
#             pepsi-blue         28        109      0.732      0.945      0.903       0.56
#        pepsi-blue-chai         23         61      0.553      0.836      0.735      0.566
#        pepsi-chanhmuoi          9         29          1      0.125      0.354      0.186
#           pepsi-yellow          4          9          1          0     0.0527     0.0358
# reveive-chanhmuoi-chai          2          4          1          0          0          0
#  revive-chanhmuoi-chai         24         78      0.776      0.833      0.872      0.616
#           revive-white          3          9          1          0          0          0
#      revive-white-chai         28         85      0.673      0.906      0.811      0.592
#       string-cafe-chai         10         28      0.871      0.357      0.558      0.401
#             string-red         23         76      0.784      0.882      0.896      0.571
#        string-red-chai         31        117      0.743      0.915      0.914      0.624
#          string-yellow         10         29      0.223     0.0799      0.259      0.182
#     string-yellow-chai         18         46      0.737      0.739      0.836       0.61
#            twister-cam         30         82      0.752      0.939      0.928      0.641
#        twister-cam-lon         10         37      0.644      0.676      0.698      0.488
#           twister-cam2          4          6      0.461      0.167      0.198      0.115
#            twister-dau          7         10      0.498      0.793      0.568      0.343
# Speed: 0.2ms preprocess, 1.5ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/runs/detect/train3

# %%
import os
from IPython.display import Image, display
import pandas as pd
import matplotlib.pyplot as plt

# Ruta a resultados
results_path = f'runs/detect/train3'

print(f"Resultados en: {results_path}\n")

# Mostrar imágenes principales
print("Visualizaciones")

imgs = {
    'Curvas de entrenamiento': 'results.png',
    'Predicciones de validación': 'val_batch0_pred.jpg',
    'Ground Truth': 'val_batch0_labels.jpg',
    'Matriz de confusión': 'confusion_matrix.png'
}

for titulo, archivo in imgs.items():
    path = f'{results_path}/{archivo}'
    if os.path.exists(path):
        print(f"\n{titulo}:")
        display(Image(filename=path, width=800))

# Métricas finales
print("Metricas")

df = pd.read_csv(f'{results_path}/results.csv')
ultima_epoca = df.iloc[-1]

print(f"\nÉpoca final: {int(ultima_epoca['epoch'])}")
print(f"mAP50 (Detección): {ultima_epoca['metrics/mAP50(B)']:.4f}")
print(f"mAP50-95 (Detección): {ultima_epoca['metrics/mAP50-95(B)']:.4f}")
#print(f"mAP50 (Segmentación): {ultima_epoca['metrics/mAP50(M)']:.4f}")
#print(f"mAP50-95 (Segmentación): {ultima_epoca['metrics/mAP50-95(M)']:.4f}")

print("\nEntrenamiento completado")
print(f"Mejor modelo guardado en: {results_path}/weights/best.pt")
# Out:
# Resultados en: runs/detect/train3
#
# Visualizaciones
#
# Curvas de entrenamiento:
# Predicciones de validación:
# Ground Truth:
# Matriz de confusión:
# Metricas
#
# Época final: 20
# mAP50 (Detección): 0.5333
# mAP50-95 (Detección): 0.3674
#
# Entrenamiento completado
# Mejor modelo guardado en: runs/detect/train3/weights/best.pt

# %%
model = YOLO('runs/detect/train3/weights/best.pt')

img_path = 'drinks.v1i.yolov11/test/images/image_183_jpg.rf.b5a901161f058643beec2ebd30020614.jpg'

resultados = model(img_path)

print(f"Objetos detectados inicialmente: {len(resultados[0].boxes)}")
# Out:
# image 1/1 /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/drinks.v1i.yolov11/test/images/image_183_jpg.rf.b5a901161f058643beec2ebd30020614.jpg: 640x640 2 7ups, 2 7up-chais, 6 aquafinas, 1 mirinda-me, 1 mirinda-sodakem, 1 olong-tea, 3 olong-teapluss, 2 pepsi-blues, 1 pepsi-blue-chai, 2 revive-white-chais, 1 string-red, 2 string-red-chais, 2 string-yellow-chais, 1 twister-cam-lon, 2.6ms
# Speed: 1.6ms preprocess, 2.6ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
# Objetos detectados inicialmente: 27

# %%
from collections import Counter

UMBRAL_CONF = 0.4

prediccion = resultados[0]
cajas_totales = prediccion.boxes

boxes_filtradas = [box for box in cajas_totales if box.conf > UMBRAL_CONF]

print(f"Objetos reales tras filtrar: {len(boxes_filtradas)}")

ids_clases = [int(box.cls) for box in boxes_filtradas]

conteos = Counter(ids_clases)

print("\nREPORTE DE INVENTARIO:")
nombres_clases = model.names

for clase_id, cantidad in conteos.items():
    nombre_obj = nombres_clases[clase_id]
    print(f" -> {nombre_obj}: {cantidad} unidades")
# Out:
# Objetos reales tras filtrar: 25
#
# REPORTE DE INVENTARIO:
#  -> aquafina: 6 unidades
#  -> pepsi-blue: 2 unidades
#  -> 7up-chai: 1 unidades
#  -> olong-teaplus: 3 unidades
#  -> string-red-chai: 2 unidades
#  -> string-yellow-chai: 1 unidades
#  -> mirinda-sodakem: 1 unidades
#  -> olong-tea: 1 unidades
#  -> mirinda-me: 1 unidades
#  -> pepsi-blue-chai: 1 unidades
#  -> revive-white-chai: 2 unidades
#  -> 7up: 2 unidades
#  -> twister-cam-lon: 1 unidades
#  -> string-red: 1 unidades

# %%
# %matplotlib inline

import cv2
import matplotlib.pyplot as plt

def visualizar_conteo(prediccion, boxes_filtradas, conteos, umbral):

    prediccion.boxes = prediccion.boxes[prediccion.boxes.conf > umbral]
    img_resultado = prediccion.plot()

    img_rgb = cv2.cvtColor(img_resultado, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(12,8))
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(f"Detección con Umbral: {umbral}")
    plt.show()

visualizar_conteo(resultados[0], boxes_filtradas, conteos, UMBRAL_CONF)

# %%
def analizar_estanteria(ruta_imagen, modelo, umbral=0.4):
    resultados = modelo(ruta_imagen)
    pred = resultados[0]

    boxes_filtradas = [box for box in pred.boxes if box.conf > umbral]

    return len(boxes_filtradas)

# %%
analizar_estanteria("drinks.v1i.yolov11/test/images/image_183_jpg.rf.b5a901161f058643beec2ebd30020614.jpg", model)
# Out:
# image 1/1 /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/drinks.v1i.yolov11/test/images/image_183_jpg.rf.b5a901161f058643beec2ebd30020614.jpg: 640x640 2 7ups, 2 7up-chais, 6 aquafinas, 1 mirinda-me, 1 mirinda-sodakem, 1 olong-tea, 3 olong-teapluss, 2 pepsi-blues, 1 pepsi-blue-chai, 2 revive-white-chais, 1 string-red, 2 string-red-chais, 2 string-yellow-chais, 1 twister-cam-lon, 6.9ms
# Speed: 18.9ms preprocess, 6.9ms inference, 8.7ms postprocess per image at shape (1, 3, 640, 640)
# 25

# %%
import glob

rutas_test = glob.glob("drinks.v1i.yolov11/test/images/*.jpg")
print(rutas_test)
for ruta in rutas_test[:3]:
    total = analizar_estanteria(ruta, model)
    print(f"Imagen: {ruta}")
    print(f"Total productos detectados: {total}\n")
# Out:
# ['drinks.v1i.yolov11/test/images/image_166_jpg.rf.c060a83c6426d25b75c2cb663873b6d0.jpg', 'drinks.v1i.yolov11/test/images/image_162_jpg.rf.8223373bf2ea60e4e91c46a15c32507f.jpg', 'drinks.v1i.yolov11/test/images/107_jpg.rf.b9c49d9d769488889c4f964fc12396d7.jpg', 'drinks.v1i.yolov11/test/images/40_jpg.rf.2a46e0d9abe1c2150f536dacd736f658.jpg', 'drinks.v1i.yolov11/test/images/image_97_jpg.rf.f7f8c4c14ee7e7ae9a26a724fb703739.jpg', 'drinks.v1i.yolov11/test/images/image_109_jpg.rf.f3d5c258de0cc1b529752a3de7c14019.jpg', 'drinks.v1i.yolov11/test/images/19_jpg.rf.768f4668aad6a0142f86bfc51eae75de.jpg', 'drinks.v1i.yolov11/test/images/11_jpg.rf.c2c3668090a43c328fe4a24ff31d83fd.jpg', 'drinks.v1i.yolov11/test/images/92_jpg.rf.9bf71647d2579e978d3334060acc7bce.jpg', 'drinks.v1i.yolov11/test/images/17_jpg.rf.1c5c6ad84cb7dea7c406c86e0c12321c.jpg', 'drinks.v1i.yolov11/test/images/image_37_jpg.rf.94b2e9bba1d43568e623f5ee41268229.jpg', 'drinks.v1i.yolov11/test/images/image_154_jpg.rf.5dcf2d0c379dde492aaf0eb50ad4edc4.jpg', 'drinks.v1i.yolov11/test/images/87_jpg.rf.51bb7f756a35a37d04e0aaa0d6b0a535.jpg', 'drinks.v1i.yolov11/test/images/image_72_jpg.rf.bf00d5cab0518fbff45dea4bfea8e90e.jpg', 'drinks.v1i.yolov11/test/images/image_183_jpg.rf.b5a901161f058643beec2ebd30020614.jpg', 'drinks.v1i.yolov11/test/images/image_189_jpg.rf.bd92a866c7945ff2a502c07262f52381.jpg', 'drinks.v1i.yolov11/test/images/image_53_jpg.rf.a5b96ef8d257deb09095fe98cd479c5a.jpg', 'drinks.v1i.yolov11/test/images/85_jpg.rf.0da7e34861a534c63f64badd1d6b2b3a.jpg', 'drinks.v1i.yolov11/test/images/image_139_jpg.rf.fb04851defa3b297e278a5f7ca2a7f81.jpg', 'drinks.v1i.yolov11/test/images/image_161_jpg.rf.308e5ee34590369fcb97d2a7fd800463.jpg', 'drinks.v1i.yolov11/test/images/109_jpg.rf.cc543c7a1a9825bec9cd3041762e23ef.jpg', 'drinks.v1i.yolov11/test/images/image_159_jpg.rf.7f7b6085c038d686ddcda2687db436bd.jpg', 'drinks.v1i.yolov11/test/images/image_115_jpg.rf.e9ef76de811152e53cfb09c8d74ae4fb.jpg', 'drinks.v1i.yolov11/test/images/image_147_jpg.rf.233d71e9ce47ad13451f8d2a82f3fba1.jpg', 'drinks.v1i.yolov11/test/images/43_jpg.rf.09c0188e3451b65e9f50744102294e58.jpg', 'drinks.v1i.yolov11/test/images/77_jpg.rf.452e40ca4a605de50aebde45b77f4f3d.jpg', 'drinks.v1i.yolov11/test/images/image_108_jpg.rf.e939fe21bab88a321210a44c89915cca.jpg', 'drinks.v1i.yolov11/test/images/image_10_jpg.rf.588474705db8b52d2c305451e36bc3c9.jpg', 'drinks.v1i.yolov11/test/images/36_jpg.rf.54c0be0464128c77432ad8be817eb7c1.jpg']
#
# image 1/1 /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/drinks.v1i.yolov11/test/images/image_166_jpg.rf.c060a83c6426d25b75c2cb663873b6d0.jpg: 640x640 2 7ups, 2 aquafinas, 1 mirinda-cam, 1 mirinda-me, 7 mirinda-xaxi-chais, 5 olong-teas, 3 pepsi-blues, 7 revive-chanhmuoi-chais, 2 revive-white-chais, 2 string-reds, 4 string-red-chais, 4 twister-cams, 3.3ms
# Speed: 1.2ms preprocess, 3.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Imagen: drinks.v1i.yolov11/test/images/image_166_jpg.rf.c060a83c6426d25b75c2cb663873b6d0.jpg
# Total productos detectados: 35
#
#
# image 1/1 /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/drinks.v1i.yolov11/test/images/image_162_jpg.rf.8223373bf2ea60e4e91c46a15c32507f.jpg: 640x640 2 7ups, 2 7up-chais, 2 aquafinas, 1 mirinda-me, 1 mirinda-xaxi-chai, 2 olong-teapluss, 2 pepsi-blues, 1 pepsi-blue-chai, 4 revive-white-chais, 1 string-red, 5 string-red-chais, 3 twister-daus, 3.5ms
# Speed: 4.3ms preprocess, 3.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Imagen: drinks.v1i.yolov11/test/images/image_162_jpg.rf.8223373bf2ea60e4e91c46a15c32507f.jpg
# Total productos detectados: 21
#
#
# image 1/1 /home/ciabd14/Escritorio/CE_IABD/MIA/UNIDAD3/Actividad3_6 ConteoObjetos/drinks.v1i.yolov11/test/images/107_jpg.rf.b9c49d9d769488889c4f964fc12396d7.jpg: 640x640 3 7up-chais, 2 aquafinas, 7 olong-teas, 1 olong-teaplus, 3 pepsi-blues, 3 pepsi-blue-chais, 6 revive-white-chais, 8 string-reds, 4 string-red-chais, 4.7ms
# Speed: 2.1ms preprocess, 4.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# Imagen: drinks.v1i.yolov11/test/images/107_jpg.rf.b9c49d9d769488889c4f964fc12396d7.jpg
# Total productos detectados: 28
