# %% [markdown]
# # COMPARATIVA APRENDIZAJE SUPERVISADO - APRENDIZAJE NO SUPERVISADO

# %%
# Importaciones
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Dataset

# %%
X, y = make_blobs(n_samples=300, centers=3, random_state=42)

plt.scatter(X[:,0], X[:,1], c=y)
plt.title("Dataset con etiquetas reales")
plt.show()

# %% [markdown]
# ## Modelo Supervisado

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

modelo_sup = LogisticRegression()
modelo_sup.fit(X_train, y_train)

y_pred = modelo_sup.predict(X_test)

print("Accuracy supervisado:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy supervisado: 1.0

# %% [markdown]
# ## Visualización Modelo Supervisado

# %%
plt.scatter(X_test[:,0], X_test[:,1], c=y_pred)
plt.title("Predicciones modelo supervisado")
plt.show()

# %% [markdown]
# ## Modelo k - Means

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)

clusters = kmeans.labels_

# %% [markdown]
# ## Visualización K - Means

# %%
plt.scatter(X[:,0], X[:,1], c=clusters)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], 
            color='red', marker='X', s=200)

plt.title("Clusters encontrados por K-Means")
plt.show()

# %% [markdown]
# ## Comparación

# %%
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.scatter(X[:,0], X[:,1], c=y)
plt.title("Etiquetas reales")

plt.subplot(1,2,2)
plt.scatter(X[:,0], X[:,1], c=clusters)
plt.title("Clusters K-Means")

plt.show()

# %% [markdown]
# ## Revisión del Ejercicio
# ### Preguntas:
#
# 1. ¿Coinciden los clusters con las clases reales?
#     -   No cesesariamente porque el modelo no sabe lo que esta buscando ya que no es supervisado.
#
# 2. ¿Por qué K-Means no siempre acierta?
#     -   Porque no sabe lo que esta buscando y depende del numero de cluster.
#
# 3. ¿Qué ventaja tiene el modelo supervisado?
#     -   Sabe cuantos grupos o clusters buscar.
#
# 4. ¿En qué casos usarías K-Means?
#     -   En casos en los que
