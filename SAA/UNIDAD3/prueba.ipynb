# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

datos = [5, 7, 8, 8, 9, 10, 10, 14, 14, 15, 20]
print("Media:", np.mean(datos))
print("Mediana:", np.median(datos))
print("Varianza:", np.var(datos))
print("Cuartiles:", np.percentile(datos,[25, 50, 75]))
plt.boxplot(datos)
plt.show()
# Out:
# Media: 10.909090909090908
# Mediana: 10.0
# Varianza: 17.355371900826448
# Cuartiles: [ 8. 10. 14.]

# %%
df = pd.read_csv("prueba.csv", sep=";")
df.head(1000)
# Out:
#      Ítem   Año
# 0       1  2013
# 1       2  2018
# 2       3  2009
# 3       4  1999
# 4       5  1996
# ..    ...   ...
# 995   996  2015
# 996   997  2017
# 997   998  2016
# 998   999  2014
# 999  1000  2014
#
# [1000 rows x 2 columns]

# %%
for i, row in df.iterrows():
    valor = row["Año"]

    # Borrar filas que sean igual a "N.V." o vacias
    if valor == "N.V." or valor is None:
        df.drop(index=i, inplace=True)
    else:
        print(valor)

# Pasar año a int porque por defecto es un string
df["Año"] = df["Año"].astype(int)

print("Media:", np.mean(df["Año"]))
print("Mediana:", np.median(df["Año"]))
print("Varianza:", np.var(df["Año"]))
print("Cuartiles:", np.percentile(df["Año"],[25, 50, 75]))
# Out:
# 2013
# 2018
# 2009
# 1999
# 1996
# 1998
# 2010
# 1995
# 2015
# 2011
# 2016
# 2016
# 2018
# 1970
# 1946
# 2015
# 1962
# 2019
# 2018
# 2004
# 2013
# 2016
# 1931
# 2010
# 1979
# 1946
# 2004
# 2005
# 2020
# 2014
# 1985
# 1929
# 1999
# 2007
# 2012
# 2017
# 2009
# 2008
# 2016
# 2011
# 2017
# 2015
# 2017
# 1985
# 2018
# 2010
# 2014
# 2006
# 2005
# 2004
# 2000
# 2007
# 2015
# 2006
# 2008
# 2003
# 2016
# 2005
# 2002
# 1991
# 1994
# 2000
# 1990
# 2014
# 1989
# 1987
# 2017
# 2015
# 2014
# 2013
# 1996
# 1986
# 2016
# 2008
# 2015
# 1981
# 2007
# 2016
# 2001
# 1986
# 2016
# 2004
# 2006
# 2017
# 2016
# 2015
# 1985
# 2017
# 2012
# 2006
# 1968
# 2018
# 1964
# 1982
# 2015
# 1995
# 1999
# 1974
# 1998
# 2015
# 2012
# 2009
# 2017
# 2000
# 2005
# 2011
# 2010
# 2011
# 1983
# 1955
# 1980
# 2005
# 1972
# 2004
# 2010
# 2015
# 1987
# 2015
# 2016
# 1953
# 2000
# 2015
# 2019
# 2013
# 2006
# 2005
# 2006
# 2007
# 1986
# 2007
# 2016
# 1982
# 1987
# 2007
# 1955
# 2019
# 2016
# 1958
# 2018
# 2018
# 2012
# 1995
# ...
