# %% [markdown]
# # Programación con IA Generativa (GROQ)

# %%
# Instalar la librería oficial de Groq
# !pip install groq
# Instalar python-dotenv para la gestión de variables
# !pip install python-dotenv
# Out:
# Requirement already satisfied: groq in /home/ciabd14/anaconda3/lib/python3.13/site-packages (1.1.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from groq) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from groq) (2.10.3)
# Requirement already satisfied: sniffio in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->groq) (3.7)
# Requirement already satisfied: certifi in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->groq) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/ciabd14/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->groq) (2.27.1)
# Requirement already satisfied: python-dotenv in /home/ciabd14/anaconda3/lib/python3.13/site-packages (1.1.0)

# %%
import os
from dotenv import load_dotenv

# Cargar variables del archivo .env
load_dotenv("clave.env")
# La variable queda disponible en el sistema automáticamente
# Out:
# True

# %%
import os
from groq import Groq

# Inicializar el cliente de Groq
client = Groq()

# Definir la ruta del archivo de audio
filename = "informatica.mp3"

# Proceso de apertura y transcripción
with open(filename, "rb") as file:
    transcription = client.audio.transcriptions.create(
    file=file, # Archivo de audio binario
    model="whisper-large-v3-turbo", # Modelo seleccionado
    prompt="Contexto o palabras clave", # Opcional para mejorar precisión
    response_format="verbose_json", # Formato detallado de salida
    language="es", # Idioma del audio (ISO-639-1)
    temperature=0.0 # Mayor determinismo (0.0)
)
    
# Resultado final
print(transcription.text)
# Out:
#  La informática ha transformado el mundo en pocas décadas. Gracias a los microprocesanores, hoy llevamos en el bolsillo más potencia de cálculo que la usada para llegar a la luna. Los algoritmos y el software están detrás de casi todo, desde las redes sociales hasta los diagnósticos médicos. Sin duda, la informática es el motor invisible de la sociedad moderna.
