# %% [markdown]
# # 1. Preparación del Entorno

# %%
# .env
# GROQ_API_KEY=tu_clave_groq
# GEMINI_API_KEY=tu_clave_gemini

# !pip install groq google-genai python-dotenv

# %% [markdown]
# # 2. Ejercicio 1: El impacto del Rol system (Groq)

# %%
import os
from groq import Groq
from dotenv import load_dotenv

load_dotenv()

client = Groq()

codigo_a_revisar = "def suma(a, b): return a+b"

# CONFIGURACIÓN A: Sin rol de sistema (comportamiento genérico)
res_generica = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": f"Revisa este código:\n{codigo_a_revisar}"}],
)

# CONFIGURACIÓN B: Con rol de sistema (comportamiento experto)
res_experta = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "system",
            "content": (
                "Eres un Ingeniero de Software Senior en Google. "
                "Tu tono es crítico, técnico y breve. "
                "Solo respondes con sugerencias de optimización o errores."
            ),
        },
        {"role": "user", "content": f"Revisa este código:\n{codigo_a_revisar}"},
    ],
)

print("--- RESPUESTA GENÉRICA ---")
print(res_generica.choices[0].message.content)

print("\n--- RESPUESTA EXPERTA (SYSTEM ROLE) ---")
print(res_experta.choices[0].message.content)
# Out:
# --- RESPUESTA GENÉRICA ---
# El código que has proporcionado es una función simple en Python que suma dos números. Aquí te dejo una revisión del código con algunas sugerencias para mejorarlo:
#
# ```python
# def suma(a, b):
#     """
#     Calcula la suma de dos números.
#
#     Args:
#         a (int o float): El primer número.
#         b (int o float): El segundo número.
#
#     Returns:
#         int o float: La suma de a y b.
#     """
#     return a + b
# ```
#
# He realizado los siguientes cambios:
#
# 1. **Agregué una documentación**: La función ahora tiene una documentación que describe lo que hace, los parámetros que recibe y lo que devuelve. Esto es útil para que otros desarrolladores puedan entender cómo funciona la función.
# 2. **Mejoré la indentación**: La indentación es importante en Python, ya que define el bloque de código que pertenece a una función o estructura de control. En este caso, la indentación es correcta.
# 3. **Agregué tipos de datos**: En la documentación, especifico que `a` y `b` pueden ser enteros (`int`) o números en coma flotante (`float`). Esto ayuda a que otros desarrolladores sepan qué tipo de datos pueden pasar a la función.
# 4. **No cambié la lógica**: La función sigue siendo simple y efectiva. La lógica para sumar dos números es correcta y no requiere cambios.
#
# En general, el código es conciso y fácil de entender. Sin embargo, en Python, es común utilizar nombres de funciones más descriptivos y evitar nombres que puedan ser fácilmente confundidos con funciones built-in del lenguaje. Por ejemplo, podrías considerar renombrar la función a `sumar_numeros` o `calcular_suma`.
#
# --- RESPUESTA EXPERTA (SYSTEM ROLE) ---
# La función falta un control de tipos y una descripción de su propósito. Debería ser:
#
# ```python
# def suma(a: int, b: int) -> int:
#     """
#     Retorna la suma de dos números enteros.
#
#     Args:
#         a (int): Primer número a sumar.
#         b (int): Segundo número a sumar.
#
#     Returns:
#         int: La suma de a y b.
#     """
#     return a + b
# ```
#
# Además, sería prudente agregar una verificación de tipos para evitar errores en tiempo de ejecución:
#
# ```python
# def suma(a: int, b: int) -> int:
#     """
#     Retorna la suma de dos números enteros.
#
#     Args:
#         a (int): Primer número a sumar.
#         b (int): Segundo número a sumar.
#
#     Returns:
#         int: La suma de a y b.
#
#     Raises:
#         TypeError: Si a o b no son números enteros.
#     """
#     if not isinstance(a, int) or not isinstance(b, int):
#         raise TypeError("Ambos argumentos deben ser números enteros")
#     return a + b
# ```

# %% [markdown]
# # 3. Ejercicio 2: Memoria y el Rol assistant (Groq)

# %%
# Continuando en el mismo archivo o uno nuevo
historial = [
    {
        "role": "system",
        "content": "Eres un tutor de Python."
    },
    {
        "role": "user",
        "content": "Hola, me llamo Carlos y quiero aprender listas."
    },
    {
        "role": "assistant",
        "content": (
            "¡Hola Carlos! Encantado. Una lista es una colección ordenada. "
            "¿Quieres ver un ejemplo?"
        )
    },
    {
        "role": "user",
        "content": "¿Cómo me llamo y qué estábamos hablando?"
    }
]

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=historial
)

print("\n--- PRUEBA DE MEMORIA ---")
print(response.choices[0].message.content)
# Out:
# --- PRUEBA DE MEMORIA ---
# Te llamas Carlos y estábamos hablando sobre aprender listas en Python. ¿Quieres que comenzemos con algunos conceptos básicos sobre listas?

# %% [markdown]
# # 4. Ejercicio 3: Implementación con Gemini 2.5

# %%
from google import genai
from dotenv import load_dotenv
import os

load_dotenv()

# El cliente detecta GEMINI_API_KEY automáticamente
client = genai.Client()

# Ejemplo de uso con Gemini 2.5 Flash
prompt_tecnico = """
Explica el concepto de 'Decoradores' en Python.
Incluye un ejemplo de código y cómo se aplicaría en un entorno real
(ej. logging).
Responde en formato Markdown.
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt_tecnico
)

print("--- ANÁLISIS DE GEMINI 2.5 ---")
print(response.text)
# Out:
# --- ANÁLISIS DE GEMINI 2.5 ---
# En Python, un **decorador** es un patrón de diseño que permite añadir funcionalidades a una función o método existente sin modificar su código fuente directamente. En esencia, un decorador es una función que toma otra función como argumento, le añade alguna funcionalidad y luego devuelve la nueva función modificada.
#
# Piensa en ellos como "envoltorios" o "modificadores" para funciones.
#
# ## Conceptos Clave
#
# Para entender los decoradores, es fundamental comprender dos conceptos previos en Python:
#
# 1.  **Las funciones son objetos de primera clase:** En Python, las funciones pueden ser tratadas como cualquier otra variable. Esto significa que puedes:
#     *   Asignarlas a variables.
#     *   Pasarlas como argumentos a otras funciones.
#     *   Devolverlas como resultado de otras funciones.
# 2.  **Funciones anidadas y closures:** Una función puede definirse dentro de otra función. Si la función interna accede a variables del ámbito de la función externa y la función externa devuelve la función interna, se crea un *closure*. El closure "recuerda" el entorno en el que fue creado.
#
# ## ¿Cómo funcionan los decoradores?
#
# Un decorador se define como una función que:
# 1.  Acepta una función (`func`) como argumento.
# 2.  Define una función interna (`wrapper` o `envoltorio`) que:
#     *   Ejecuta código *antes* de llamar a la función original.
#     *   Llama a la función original (`func`).
#     *   Ejecuta código *después* de llamar a la función original.
#     *   Asegura que la función interna (`wrapper`) pueda aceptar cualquier argumento (`*args`, `**kwargs`) que la función original esperaría.
#     *   Retorna el valor de la función original.
# 3.  Retorna la función interna (`wrapper`).
#
# La sintaxis especial `@nombre_decorador` justo encima de la definición de una función es "azúcar sintáctico" para:
# `mi_funcion = nombre_decorador(mi_funcion)`
#
# ---
#
# ## Ejemplo de Código Básico
#
# Vamos a crear un decorador simple que imprime un mensaje antes y después de ejecutar una función.
#
# ```python
# import functools
#
# # 1. Definición del decorador
# def mi_primer_decorador(func):
#     # functools.wraps es importante para preservar los metadatos de la función original
#     # (como __name__, __doc__, etc.)
#     @functools.wraps(func)
#     def wrapper(*args, **kwargs):
#         print(f"--- Antes de ejecutar '{func.__name__}' ---")
#
#         # Llama a la función original con sus argumentos
#         resultado = func(*args, **kwargs)
#
#         print(f"--- Después de ejecutar '{func.__name__}' ---")
#         return resultado # Retorna el resultado de la función original
#     return wrapper # Retorna la función interna (el envoltorio)
#
# # 2. Aplicación del decorador
# @mi_primer_decorador
# def saludar(nombre):
#     """Esta función saluda a una persona."""
#     print(f"¡Hola, {nombre}!")
#     return f"Saludo para {nombre}"
#
# @mi_primer_decorador
# def sumar(a, b):
#     """Esta función suma dos números."""
#     print(f"Calculando la suma de {a} y {b}...")
#     return a + b
#
# # 3. Uso de las funciones decoradas
# print("--- Ejecutando saludar ---")
# saludar("Mundo")
# print("\n--- Ejecutando sumar ---")
# resultado_suma = sumar(5, 3)
# print(f"Resultado de la suma: {resultado_suma}")
#
# print(f"\nNombre de la función saludar: {saludar.__name__}") # Muestra 'saludar' gracias a functools.wraps
# print(f"Docstring de la función sumar: {sumar.__doc__}") # Muestra la docstring de sumar gracias a functools.wraps
# ```
#
# **Explicación del código:**
# *   `mi_primer_decorador` es la función decoradora. Toma una función `func` como argumento.
# *   `wrapper` es la función interna que envuelve a `func`. Contiene la lógica adicional (los `print` antes y después) y luego llama a la `func` original.
# *   `@functools.wraps(func)` es crucial. Sin él, al decorar una función, el nombre (`__name__`) y la cadena de documentación (`__doc__`) de la función decorada se perderían y mostrarían los de la función `wrapper`. `functools.wraps` copia los metadatos de la función original a la función `wrapper`.
# *   Las funciones `saludar` y `sumar` son *decoradas* con `@mi_primer_decorador`. Cuando las llamas, en realidad estás llamando a la función `wrapper` que, a su vez, ejecuta el código adicional y luego la lógica original de `saludar` o `sumar`.
#
# ---
#
# ## Aplicación en un Entorno Real: Logging
#
# Un caso de uso muy común para los decoradores es añadir **logging** (registro de eventos) a funciones sin tener que dispersar el código de logging por todo el programa.
#
# Queremos registrar cuándo una función comienza, sus argumentos, su resultado y cuándo finaliza.
#
# ```python
# import logging
# import functools
# import time
#
# # Configuración básica del logging
# logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
#
# def log_ejecucion(func):
#     """
#     Decorador que registra el inicio, fin, argumentos y resultado de una función.
#     """
#     @functools.wraps(func)
#     def wrapper(*args, **kwargs):
#         func_name = func.__name__
#
#         # Convertir argumentos a una cadena para el log
#         args_repr = [repr(a) for a in args]
#         kwargs_repr = [f"{k}={v!r}" for k, v in kwargs.items()]
#         signature = ", ".join(args_repr + kwargs_repr)
#
#         logging.info(f"START: Función '{func_name}' llamada con args: ({signature})")
#         start_time = time.time()
#
#         try:
#             result = func(*args, **kwargs)
#             end_time = time.time()
#             duration = end_time - start_time
#             logging.info(f"END: Función '{func_name}' finalizada. Resultado: {result!r} (Duración: {duration:.4f}s)")
#             return result
#         except Exception as e:
#             end_time = time.time()
#             duration = end_time - start_time
#             logging.error(f"ERROR: Función '{func_name}' falló con excepción: {e!r} (Duración: {duration:.4f}s)")
#             raise # Re-lanza la excepción para no alterar el comportamiento original de la función
#
#     return wrapper
#
# # Aplicamos el decorador a nuestras funciones
# @log_ejecucion
# def calcular_area_circulo(radio):
#     """Calcula el área de un círculo dado su radio."""
#     if radio < 0:
#         raise ValueError("El radio no puede ser negativo.")
#     return 3.14159 * radio ** 2
#
# @log_ejecucion
# def saludar_personalizado(nombre, saludo="Hola"):
#     """Envía un saludo personalizado."""
#     mensaje = f"{saludo}, {nombre}!"
#     print(f"Dentro de saludar_personalizado: {mensaje}")
#     return mensaje
#
# # Ejecutamos las funciones y observamos el logging
# print("--- Ejecutando calcular_area_circulo ---")
# area = calcular_area_circulo(5)
# print(f"Área calculada: {area}\n")
#
# print("--- Ejecutando saludar_personalizado ---")
# saludo = saludar_personalizado("Alice", saludo="Buenos días")
# print(f"Saludo obtenido: {saludo}\n")
#
# print("--- Ejecutando calcular_area_circulo con error ---")
# try:
#     calcular_area_circulo(-2)
# except ValueError as e:
#     print(f"Error capturado en el exterior: {e}\n")
#
# ```
#
# **Salida (ejemplo en consola, el formato de hora puede variar):**
#
# ```
# --- Ejecutando calcular_area_circulo ---
# 2023-10-27 10:30:00,123 - INFO - START: Función 'calcular_area_circulo' llamada con args: (5)
# 2023-10-27 10:30:00,123 - INFO - END: Función 'calcular_area_circulo' finalizada. Resultado: 78.53975 (Duración: 0.0001s)
# Área calculada: 78.53975
#
# --- Ejecutando saludar_personalizado ---
# 2023-10-27 10:30:00,124 - INFO - START: Función 'saludar_personalizado' llamada con args: ('Alice', saludo='Buenos días')
# Dentro de saludar_personalizado: Buenos días, Alice!
# 2023-10-27 10:30:00,124 - INFO - END: Función 'saludar_personalizado' finalizada. Resultado: 'Buenos días, Alice!' (Duración: 0.0001s)
# Saludo obtenido: Buenos días, Alice!
#
# --- Ejecutando calcular_area_circulo con error ---
# 2023-10-27 10:30:00,125 - INFO - START: Función 'calcular_area_circulo' llamada con args: (-2)
# 2023-10-27 10:30:00,125 - ERROR - ERROR: Función 'calcular_area_circulo' falló con excepción: ValueError('El radio no puede ser negativo.') (Duración: 0.0001s)
# Error capturado en el exterior: El radio no puede ser negativo.
# ```
#
# ### Ventajas en el Escenario Real:
#
# 1.  **Separación de Responsabilidades:** El decorador `log_ejecucion` maneja toda la lógica de logging. Las funciones `calcular_area_circulo` y `saludar_personalizado` solo se preocupan de su lógica de negocio principal.
# 2.  **Reusabilidad:** Podemos aplicar `log_ejecucion` a cualquier número de funciones en nuestro código sin reescribir la lógica de logging cada vez.
# 3.  **Mantenibilidad:** Si queremos cambiar cómo se registra una ejecución (por ejemplo, añadir un ID de transacción, enviar a un sistema de monitoreo, etc.), solo necesitamos modificar el código del decorador `log_ejecucion`, y todos los lugares donde se aplica se actualizarán automáticamente.
# 4.  **Legibilidad:** La sintaxis `@log_ejecucion` es muy clara e indica inmediatamente que la función tiene una funcionalidad de logging adicional.
# 5.  **DRY (Don't Repeat Yourself):** Evitamos duplicar el código de logging en cada función.
#
# Los decoradores son una herramienta muy potente en Python para extender y modificar el comportamiento de funciones y clases de una manera limpia y modular.
